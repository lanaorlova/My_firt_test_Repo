# %% [markdown]
# <a href="https://colab.research.google.com/github/lanaorlova/My_firt_test_Repo/blob/main/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%D0%9B%D0%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Заголовок
#
# ---
#
# ## Подзаголовок
#
# * список
# * список
# * список
#
# [Погода](https://www.gismeteo.ru/weather-novosibirsk-4690/)
#
# | 1 | 2 | 3 |
# |---|---|---|
# | f | g | g |
# | h | f | 1 |
#
# ![image.png](data:image/png;base64,...)
